# %% [markdown]
# ## Impute missing data using linear interpolation
#
# <img src='./LINEAR INTERPOLATION.PNG'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sktime.datasets import load_airline
from sktime.utils.plotting import plot_series

# %%
y = load_airline()
plot_series(y);

# %% [markdown]
# ## Lets create some missing data

# %%
temp = y.copy()
# small-gap of missing data
temp[y.loc['1950-09':'1950-12'].index]=np.nan
# large-gap of missing data
temp[y.loc['1955-01':'1956-06'].index]=np.nan
temp.plot(figsize=(15,4));

# %% [markdown]
# ## Linear Interpolation

# %%
temp_imputed = temp.interpolate(method='linear')
temp_imputed.plot(figsize=(15,4));
temp_imputed.loc[temp.isnull()].plot(ls='', marker='o', c='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Linear Interpolation draws a line between known data-points to impute the missing
#
# ### `dataframe.interpolate(method='linear')`
#
# * #### For short gaps there is minimal distortion to the time series
# * #### For larger gaps there is greater distortion to the time series.
# * #### If the time interval between data-points are not uniform then set the `method=time`<br> `dataframe.interpolate(method='time')`
